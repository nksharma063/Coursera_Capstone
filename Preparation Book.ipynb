# %% [markdown]
# <h3>Thank You to all professors and with blessing of almighty we are starting the epic journey of applied data science capstone project.</h3>
# <h5> Thank you Mr alex, Data Scientist at IBM to help us out at each and every step</h5>

# %%
import pandas as pd

# %%
import numpy as np

# %%
print("Hello Capstone Project Course! I hope i will be able to complete this project and understand the end to end process while i skipped python for visualisation, ALL the best!!Thank You every one")
# Out:
# Hello Capstone Project Course! I hope i will be able to complete this project and understand the end to end process while i skipped python for visualisation, ALL the best!!Thank You every one
